# %% [markdown]
# <a href="https://colab.research.google.com/github/SharjeelZahoor/Problem-Solving-Interview-Problems/blob/main/k%20times%20left%20side%20array%20rotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rotate the list to the left by k steps.

# %% [markdown]
# give the list members according to the index given in queries list

# %%
def circularArrayRotation(list1, k):
  n = len(list1)
  lst2=[]
  k = k%n
  for i in range(k,n):
    lst2.append(list1[i])
  for i in range(k):
    lst2.append(list1[i])
  return lst2





list1 = [2, 4, 6, 8, 10, 12, 14]
k = 8
circularArrayRotation(list1, k)
# Out:
# [4, 6, 8, 10, 12, 14, 2]

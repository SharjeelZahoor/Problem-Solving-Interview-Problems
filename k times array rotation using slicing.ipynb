# %% [markdown]
# <a href="https://colab.research.google.com/github/SharjeelZahoor/Problem-Solving-Interview-Problems/blob/main/k%20times%20array%20rotation%20using%20slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rotate the list to the right by k steps.

# %% [markdown]
# give the list members according to the index given in queries list

# %%
def circularArrayRotation(a, k):
    n = len(a)
    k = k % n
    rotated_array = a[-k:] + a[:-k]
    # values at the specified indices
    return rotated_array


a = [2, 4, 6, 8, 10, 12]
k = 8
circularArrayRotation(a,k)
# Out:
# [10, 12, 2, 4, 6, 8]

# %% [markdown]
# <a href="https://colab.research.google.com/github/SharjeelZahoor/Problem-Solving-Interview-Problems/blob/main/Two%20string%20another%20efficient%20solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Two Strings 🧠💻
#
# The challenge was to determine if two strings share any common characters and
#  return a result based on that. To tackle this, I used Python’s built-in data structures to efficiently compare the strings and find if they had overlapping characters.
#
# 📚 Key takeaway: Leveraging data structures like sets not only simplified the problem but also improved performance. It's always exciting to see how small optimizations can make a big difference!

# %%
def twoStrings(s1, s2):
    # Write your code here
    s3 = s1 + s2
    s1 = set(s1)
    s2 = set(s2)
    if len(s1) + len(s2) == len(set(s3)):
        return "NO"
    else:
        return "YES"


s1 = "hello"
s2 = "world"
result =f"IS {s1} and {s2} has overlapping characters : \n\t Answer is {twoStrings(s1, s2)}\n"
print(result)
s1 = "hi"
s2 = "world"
result = f"IS {s1} and {s2} has overlapping characters : \n\t Answer is {twoStrings(s1, s2)}\n"
print(result)
# Out:
# IS hello and world has overlapping characters :
# 	 Answer is YES
#
# IS hi and world has overlapping characters :
# 	 Answer is NO
